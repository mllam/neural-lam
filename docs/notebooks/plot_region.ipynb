# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import cartopy.crs as ccrs
import numpy as np
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import cartopy

import neural_lam.config as nlc

# %% [markdown]
# # DANRA

# %%
danra_interior_config = "/home/joel/repos/neural-lam/configs/danra_example_model1/danra_model1_config.yaml"
danra_boundary_config = "/home/joel/repos/neural-lam/configs/danra_example_model1/era_model1_config.yaml"

# %%
danra_interior_ds = nlc.init_datastore("mdp", danra_interior_config)
danra_boundary_ds = nlc.init_datastore("mdp", danra_boundary_config)
# Out:
# 2025-02-25 10:29:20.596 | WARNING  | neural_lam.datastore.mdp:__init__:67 - Config file has been modified since zarr was created. The old zarr archive (in /home/joel/repos/neural-lam/configs/danra_example_model1/danra_model1_config.zarr) will be used.To generate new zarr-archive, move the old one first.
# 2025-02-25 10:29:20.869 | WARNING  | neural_lam.datastore.mdp:__init__:67 - Config file has been modified since zarr was created. The old zarr archive (in /home/joel/repos/neural-lam/configs/danra_example_model1/era_model1_config.zarr) will be used.To generate new zarr-archive, move the old one first.
# The loaded datastore contains the following features:
#  state   : pres_seasurface t2m u10m v10m pres0m lwavr0m swavr0m z100 z200 z400 z600 z700 z850 z925 z1000 t100 t200 t400 t600 t700 t850 t925 t1000 r100 r200 r400 r600 r700 r850 r925 r1000 u100 u200 u400 u600 u700 u850 u925 u1000 v100 v200 v400 v600 v700 v850 v925 v1000 tw100 tw200 tw400 tw600 tw700 tw850 tw925 tw1000
#  forcing : toa_radiation hour_of_day_sin hour_of_day_cos day_of_year_sin day_of_year_cos
#  static  : lsm orography
# With the following splits (over time):
#  train   : 2000-01-01T00:00 to 2000-01-07T00:00
#  val     : 2000-01-01T00:00 to 2000-01-07T00:00
#  test    : 2000-01-01T00:00 to 2000-01-07T00:00
# The loaded datastore contains the following features:
#  forcing : mean_sea_level_pressure 2m_temperature 10m_u_component_of_wind 10m_v_component_of_wind surface_pressure toa_radiation hour_of_day_sin hour_of_day_cos day_of_year_sin day_of_year_cos geopotential100 geopotential200 geopotential400 geopotential600 geopotential700 geopotential850 geopotential925 geopotential1000 temperature100 temperature200 temperature400 temperature600 temperature700 temperature850 temperature925 temperature1000 specific_humidity100 specific_humidity200 specific_humidity400 specific_humidity600 specific_humidity700 specific_humidity850 specific_humidity925 specific_humidity1000 u_component_of_wind100 u_component_of_wind200 u_component_of_wind400 u_component_of_wind600 u_component_of_wind700 u_component_of_wind850 u_component_of_wind925 u_component_of_wind1000 v_component_of_wind100 v_component_of_wind200 v_component_of_wind400 v_component_of_wind600 v_component_of_wind700 v_component_of_wind850 v_component_of_wind925 v_component_of_wind1000 vertical_velocity100 vertical_velocity200 vertical_velocity400 vertical_velocity600 vertical_velocity700 vertical_velocity850 vertical_velocity925 vertical_velocity1000
#  static  : land_sea_mask geopotential_at_surface
# With the following splits (over time):
#  train   : 2000-01-01T00:00 to 2000-01-07T00:00
#  val     : 2000-01-01T00:00 to 2000-01-07T00:00
#  test    : 2000-01-01T00:00 to 2000-01-07T00:00
# /home/joel/repos/neural-lam/neural_lam/datastore/mdp.py:200: UserWarning: no state data found in datastore
#   warnings.warn(f"no {category} data found in datastore")

# %%
danra_boundary_ds.get_lat_lon("forcing")
# Out:
# array([[  0.  ,  70.  ],
#        [  0.  ,  69.75],
#        [  0.  ,  69.5 ],
#        ...,
#        [359.75,  41.25],
#        [359.75,  41.  ],
#        [359.75,  40.75]], dtype=float32)

# %%
def plot_lam_setup(interior_ds, boundary_ds, lat_lon_extent, interior_latlon=False):
    interior_color = "salmon"
    boundary_color = "moccasin"
    alpha = 1

    global_crs = ccrs.PlateCarree()
    global_crs._threshold /= 100. # Fix a threshold to get round great circle arcs
    interior_crs = interior_ds.coords_projection

    if interior_latlon:
        interior_lat_lons = interior_ds.get_lat_lon("state")
        interior_xy = interior_crs.transform_points(
            ccrs.PlateCarree(), interior_lat_lons[:, 0], interior_lat_lons[:, 1]
        )[:, :2]
    else:
        interior_xy = interior_ds.get_xy("state")
    
    x_min, y_min = interior_xy.min(axis=0)
    x_max, y_max = interior_xy.max(axis=0)
    
    # Create figure and axis with the projected CRS
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(1, 1, 1, projection=interior_crs)
    
    # Add some map features for context
    ax.coastlines()
    ax.gridlines(draw_labels=["left", "bottom"], x_inline=False, rotate_labels=False)
    ax.add_feature(cartopy.feature.BORDERS, linestyle='-', alpha=.5)

    # Add boundary
    # Note that we can work with euclidean tools here, as this is all latlon and PlateCarree
    boundary_points = boundary_ds.get_lat_lon("forcing").copy()
    boundary_points[boundary_points[:,0] > 180, 0] = -360 + boundary_points[boundary_points[:,0] > 180, 0]
    boundary_chull = ConvexHull(boundary_points)
    #ax.scatter(boundary_points[:,0], boundary_points[:,1], transform=global_crs)
    boundary_polygon_corners = np.stack([boundary_points[vertex] for vertex in boundary_chull.vertices], axis=0)
    boundary_chull_polygon = mpatches.Polygon(boundary_polygon_corners, 
        closed=True, transform=global_crs, facecolor=boundary_color, alpha=alpha)
    ax.add_patch(boundary_chull_polygon)

    # Add the interior    
    rect = mpatches.Rectangle((x_min, y_min), (x_max - x_min), (y_max - y_min),
        facecolor=interior_color, alpha=alpha, transform=interior_crs)
    ax.add_patch(rect)

    # Add legend
    legend_elements = [
        mpatches.Patch(facecolor=interior_color, alpha=alpha, label='Interior'),
        mpatches.Patch(facecolor=boundary_color, alpha=alpha, label='Boundary'),
    ]
    ax.legend(handles=legend_elements, loc='upper left',
             frameon=True, facecolor="white", edgecolor="black", framealpha=1.0, fontsize=12)
    
    # style and show/save
    ax.set_extent(lat_lon_extent, crs=ccrs.PlateCarree())
    fig.tight_layout()

    return fig

fig = plot_lam_setup(danra_interior_ds, danra_boundary_ds, [-12, 35, 42, 70])
fig.savefig("danra_region.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# ## COSMO

# %%
# TODO Change paths
cosmo_interior_config = "/home/joel/repos/neural-lam/configs/cosmo_example/cosmo.datastore.yaml"
cosmo_boundary_config = "/home/joel/repos/neural-lam/configs/cosmo_example/era5_7_19_margin.datastore.yaml"

cosmo_interior_ds = nlc.init_datastore("mdp", cosmo_interior_config)
cosmo_boundary_ds = nlc.init_datastore("mdp", cosmo_boundary_config)
# Out:
# The loaded datastore contains the following features:
#  state   : U_lev_6 U_lev_12 U_lev_20 U_lev_27 U_lev_31 U_lev_39 U_lev_45 U_lev_60 V_lev_6 V_lev_12 V_lev_20 V_lev_27 V_lev_31 V_lev_39 V_lev_45 V_lev_60 PP_lev_6 PP_lev_12 PP_lev_20 PP_lev_27 PP_lev_31 PP_lev_39 PP_lev_45 PP_lev_60 T_lev_6 T_lev_12 T_lev_20 T_lev_27 T_lev_31 T_lev_39 T_lev_45 T_lev_60 RELHUM_lev_6 RELHUM_lev_12 RELHUM_lev_20 RELHUM_lev_27 RELHUM_lev_31 RELHUM_lev_39 RELHUM_lev_45 RELHUM_lev_60 W_lev_6 W_lev_12 W_lev_20 W_lev_27 W_lev_31 W_lev_39 W_lev_45 W_lev_60 T_2M U_10M V_10M PMSL PS TOT_PREC ASHFL_S ASOB_S ATHB_S
#  forcing : toa_radiation hour_of_day_sin hour_of_day_cos day_of_year_sin day_of_year_cos
#  static  : HSURF lsm
# With the following splits (over time):
#  train   : 2015-11-28T00:00 to 2019-09-30T00:00
#  val     : 2019-09-30T00:00 to 2019-10-30T00:00
#  test    : 2019-10-30T00:00 to 2020-10-29T00:00
# The loaded datastore contains the following features:
#  forcing : mean_sea_level_pressure 2m_temperature 10m_u_component_of_wind 10m_v_component_of_wind surface_pressure total_precipitation_6hr toa_radiation hour_of_day_sin hour_of_day_cos day_of_year_sin day_of_year_cos u_component_of_wind100hPa u_component_of_wind200hPa u_component_of_wind400hPa u_component_of_wind600hPa u_component_of_wind700hPa u_component_of_wind850hPa u_component_of_wind925hPa u_component_of_wind1000hPa v_component_of_wind100hPa v_component_of_wind200hPa v_component_of_wind400hPa v_component_of_wind600hPa v_component_of_wind700hPa v_component_of_wind850hPa v_component_of_wind925hPa v_component_of_wind1000hPa temperature100hPa temperature200hPa temperature400hPa temperature600hPa temperature700hPa temperature850hPa temperature925hPa temperature1000hPa specific_humidity100hPa specific_humidity200hPa specific_humidity400hPa specific_humidity600hPa specific_humidity700hPa specific_humidity850hPa specific_humidity925hPa specific_humidity1000hPa geopotential100hPa geopotential200hPa geopotential400hPa geopotential600hPa geopotential700hPa geopotential850hPa geopotential925hPa geopotential1000hPa vertical_velocity100hPa vertical_velocity200hPa vertical_velocity400hPa vertical_velocity600hPa vertical_velocity700hPa vertical_velocity850hPa vertical_velocity925hPa vertical_velocity1000hPa
#  static  : land_sea_mask geopotential_at_surface
# With the following splits (over time):
#  train   : 2015-11-28T00:00 to 2019-09-30T00:00
#  val     : 2019-09-30T00:00 to 2019-10-30T00:00
#  test    : 2019-10-30T00:00 to 2020-10-29T00:00
# /home/joel/repos/neural-lam/neural_lam/datastore/mdp.py:200: UserWarning: no state data found in datastore
#   warnings.warn(f"no {category} data found in datastore")

# %%
fig = plot_lam_setup(cosmo_interior_ds, cosmo_boundary_ds, [-8, 26, 34, 58], interior_latlon=True)
fig.savefig("cosmo_region.pdf", format="pdf", bbox_inches="tight")
